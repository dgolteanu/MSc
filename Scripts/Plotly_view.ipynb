# %%
import plotly

# %%
# Dengue
fig_1 = plotly.io.read_json('/Users/dolteanu/local_documents/Coding/MSc_github/Results/Dengue/Images/MoDmap_mds.json')
fig_1.update_traces(marker={'size': 5})

# %%
# Bacteria
fig_9 = plotly.io.read_json('/Users/dolteanu/local_documents/Coding/MSc_github/Results/Bacteria/Images/MoDmap_mds.json')
fig_9.update_traces(marker={'size': 5})
# fig_9.update_layout(legend_traceorder="reversed")
fig_9.update_layout(margin=dict(l=0, r=0, b=0, t=0),
                      legend_title_text="Classes")

# %%
# Nextstrain website, nextstrain gisaid
fig_4 = plotly.io.read_json('/Users/dolteanu/local_documents/Coding/MSc_github/Results/Nextstrain_gisaid/Images/MoDmap.json')
fig_4.update_traces(marker={'size': 5})
fig_4.update_layout(margin=dict(l=0, r=0, b=0, t=0),
                      legend_title_text="Gisaid Clades")

# %%
# Nextstrain website, nextstrain clades, NOT deduplicated
fig_3 = plotly.io.read_json('/Users/dolteanu/local_documents/Coding/MSc_github/Results/Nextstrain_clade/Images/MoDmap.json')
fig_3.update_traces(marker={'size': 5})

# %%
#Ontario covid gisaid clades, deduplicated
fig_2 = plotly.io.read_json('/Users/dolteanu/local_documents/Coding/MSc_github/Results/Ontario_gisaid_5/Images/MoDmap.json')
fig_2.update_traces(marker={'size': 4})
